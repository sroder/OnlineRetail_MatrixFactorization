# %%
# READ DATA
import pandas as pd
dfs = pd.read_excel('OnlineRetail.xlsx', sheet_name='OnlineRetail')

# %%
#UNIQUE Values 
#exploring the unique values of each attribute
print("Number of transactions: ", dfs['InvoiceNo'].nunique())
print("Number of products bought: ",dfs['StockCode'].nunique())
print("Number of customers:", dfs['CustomerID'].nunique() )
print("Percentage of customers NA: ", round(dfs['CustomerID'].isnull().sum() * 100 / len(dfs),2),"%" )
print('Number of countries: ',dfs['Country'].nunique())
# Out:
# ('Number of transactions: ', 25900)
# ('Number of products bought: ', 4070)
# ('Number of customers:', 4372)
# ('Percentage of customers NA: ', 24.0, '%')
# ('Number of countries: ', 38)

# %%
#######--------------------------------------------------------------------------------------------------------------#####
# Cancelled invoices

# As mentioned in the description of the dataset, some InvoiceNo start with the letter "c" = cancelled. Let's see if our hypothesis is correct about the negative quantity: -80995.
# We will look for the list of cancelled invoices and check if there is an invoice with that quantity.

# %%
#get canceled transactions
cancelled_orders = dfs[dfs['InvoiceNo'].astype(str).str.contains('C')]
cancelled_orders.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
# How many canceled orders do we have?

# %%
#check how many rows our dataframe of cancelled orders contain
print("We have ",len(cancelled_orders), " cancelled orders.")
#percentage of cancelled orders in total orders
total_orders = dfs['InvoiceNo'].nunique()
cancelled_number = len(cancelled_orders)
print('Percentage of orders canceled: {}/{} ({:.2f}%) '.format(cancelled_number, total_orders, cancelled_number/total_orders*100))
# Out:
# ('We have ', 9288, ' cancelled orders.')
# Percentage of orders canceled: 9288/25900 (0.00%)

# %%
#remove canceled orders
dfs = dfs[dfs['Quantity']>0]
dfs.shape
# Out:
# (531285, 8)

# %%
#remove rows where customerID are NA
dfs.dropna(subset=['CustomerID'],how='all',inplace=True)
dfs.shape
# Out:
# (397924, 8)

# %%
###### Multiplying Quantity and UnitPrice columns to get a new column : AmountSpend########
dfs['AmountSpend'] = dfs['Quantity']*dfs['UnitPrice']

# %%
dfs.tail(5)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country  AmountSpend
# 541904 2011-12-09 12:50:00       0.85     12680.0  France        10.20
# 541905 2011-12-09 12:50:00       2.10     12680.0  France        12.60
# 541906 2011-12-09 12:50:00       4.15     12680.0  France        16.60
# 541907 2011-12-09 12:50:00       4.15     12680.0  France        16.60
# 541908 2011-12-09 12:50:00       4.95     12680.0  France        14.85

# %%
#### Check if there is a negative AmountSpend in the filtered database
#  len(DataFrame.index) is equal to number of rows
negative_amountSpend = dfs[dfs['AmountSpend'] < 0]
len(negative_amountSpend.index)
# Out:
# 0

# %%
###  Here we can see that there is no negative amount spend
## now to think about how to create User, Item matrix 
## My approach is to consider how much money did each User spent on each Item
##

# %%
## Keeping relevant coluns from the Database
matrix_setup = dfs[['StockCode','CustomerID','AmountSpend']]
matrix_setup.shape
# Out:
# (397924, 3)

# %%
matrix_setup.describe()
# Out:
#           CustomerID    AmountSpend
# count  397924.000000  397924.000000
# mean    15294.315171      22.394749
# std      1713.169877     309.055588
# min     12346.000000       0.000000
# 25%     13969.000000       4.680000
# 50%     15159.000000      11.800000
# 75%     16795.000000      19.800000
# max     18287.000000  168469.600000

# %%
#UNIQUE Values 
#exploring the unique values of each attribute

print("Number of products bought: ",matrix_setup['StockCode'].nunique())
print("Number of customers:", matrix_setup['CustomerID'].nunique() )
# Out:
# ('Number of products bought: ', 3665)
# ('Number of customers:', 4339)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [16,9]

# %%
#plt.plot(a['CustomerID'])
import seaborn as sns
sns.set()
plt.hist(matrix_setup['AmountSpend'],bins=200, log=True)
plt.xlabel('Amount Spend')
plt.ylabel('Frequency')
plt.show()

# %%
# finding outliers
matrix_setup[(matrix_setup['AmountSpend'] > 5000)].count()
# Out:
# StockCode      7
# CustomerID     7
# AmountSpend    7
# dtype: int64

# %%
# removing outliers
matrix_setup = matrix_setup[(matrix_setup['AmountSpend'] < 5000)]

# %%
#UNIQUE Values 
#exploring the unique values of each attribute

print("Number of products bought: ",matrix_setup['StockCode'].nunique())
print("Number of customers:", matrix_setup['CustomerID'].nunique() )
# Out:
# ('Number of products bought: ', 3664)
# ('Number of customers:', 4338)

# %%
import numpy as np
matrix_setup['Mean_amount'] = matrix_setup.groupby(['StockCode','CustomerID'])['AmountSpend'].transform(np.mean)

# %%
#matrix_setup.groupby(['StockCode' =' 85123A','CustomerID' =' 17850.0'])
matrix_setup.loc[(matrix_setup['StockCode'] == '85123A') & (matrix_setup['CustomerID'] == 17850.0)]
# Out:
#      StockCode  CustomerID  AmountSpend  Mean_amount
# 0       85123A     17850.0         15.3    18.582353
# 49      85123A     17850.0         15.3    18.582353
# 66      85123A     17850.0         15.3    18.582353
# 278     85123A     17850.0         15.3    18.582353
# 416     85123A     17850.0         20.4    18.582353
# 3118    85123A     17850.0         15.3    18.582353
# 3142    85123A     17850.0         15.3    18.582353
# 3192    85123A     17850.0         15.3    18.582353
# 3224    85123A     17850.0         15.3    18.582353
# 3425    85123A     17850.0         15.3    18.582353
# 3443    85123A     17850.0         15.3    18.582353
# 3808    85123A     17850.0         30.6    18.582353
# 3823    85123A     17850.0         15.3    18.582353
# 4161    85123A     17850.0         30.6    18.582353
# 4182    85123A     17850.0         15.3    18.582353
# 4510    85123A     17850.0         15.3    18.582353
# 4526    85123A     17850.0         35.4    18.582353

# %%
# DataFrame.drop_duplicates(subset=None, keep='first', inplace=False)[source]
mtarix_toGO = matrix_setup.drop_duplicates(subset = ['StockCode','CustomerID'], keep = 'first')

# %%
mtarix_toGO.loc[(matrix_setup['StockCode'] == '85123A') & (matrix_setup['CustomerID'] == 17850.0)]
# Out:
#   StockCode  CustomerID  AmountSpend  Mean_amount
# 0    85123A     17850.0         15.3    18.582353

# %%
# Unique transactions = length of any column
mtarix_toGO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 266798 entries, 0 to 541908
# Data columns (total 4 columns):
# StockCode      266798 non-null object
# CustomerID     266798 non-null float64
# AmountSpend    266798 non-null float64
# Mean_amount    266798 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 9.2+ MB

# %%
#The name SurPRISE (roughly :) ) stands for Simple Python RecommendatIon System Engine.
from surprise import SVD,NMF,SVDpp,evaluate
from surprise.dataset import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.dataset import DatasetAutoFolds

# %%
from surprise.model_selection.search import GridSearchCV

# %%
# need to normalize the Mean_Amount column(which is going to be predicted) otherwise prediction takes a lot of time and also bad results
import numpy as np
std_mean_amt = np.std(mtarix_toGO['Mean_amount'])
mean = np.mean(mtarix_toGO['Mean_amount'])
print std_mean_amt
print mean
# Out:
# 52.2241310018
# 18.3891753166

# %%
# Normalized data [0,1]
mtarix_toGO['Norm_Tot_Amnt']= (mtarix_toGO['Mean_amount'] -mean)/std_mean_amt
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
lower_bound = min(mtarix_toGO['Norm_Tot_Amnt'])
upper_bound = max(mtarix_toGO['Norm_Tot_Amnt'])
print lower_bound
print upper_bound
# Out:
# -0.352120273977
# 91.114217382

# %%
sns.set()
plt.hist(mtarix_toGO['Norm_Tot_Amnt'],bins=200, log=True)
plt.xlabel('Normalized  mean Amount Spend')
plt.ylabel('Frequency of Users')
plt.show()

# %%
#define the reader  with  upper and lower bounds , also now we are predicting Normalized Total Amount column
reader = Reader(rating_scale = (lower_bound,upper_bound))
#rating_scale(:obj:`tuple`, optional): The rating scale used for every rating.  Default is ``(1, 5)``.

# Assigning data as matrix_setup
data = Dataset.load_from_df(df=mtarix_toGO[['CustomerID','StockCode','Norm_Tot_Amnt']],reader=reader)
#data = Dataset.load_from_df(df=matrix_setup[['CustomerID','StockCode','AmountSpend']],reader=None)

# %%
# check out time
import time
start_time = time.time()

# %%
#### 15th July## 1st Try PMF Grid Search
# GridSerachCv implementation 
param_grid = {'biased':[False],'n_factors':[2,5,10,50],'n_epochs': [10,50,100,500], 'lr_all': [0.1,0.01,0.001,0.0001],'reg_all': [0.1,0.01,0.001,0.0001]}
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3, n_jobs=1)

gs.fit(data)
# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])

# best MAE score
print(gs.best_score['mae'])

# combination of parameters that gave the best MAE score
print(gs.best_params['mae'])

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 0.8187842293668542
# {'lr_all': 0.01, 'reg_all': 0.01, 'biased': False, 'n_factors': 50, 'n_epochs': 100}
# 0.1862949813234869
# {'lr_all': 0.01, 'reg_all': 0.01, 'biased': False, 'n_factors': 50, 'n_epochs': 100}
# --- 162789.925 seconds ---

# %%
#12th July## 1st Try SVD
results_df = pd.DataFrame.from_dict(gs.cv_results)
results_df
# Out:
#      mean_fit_time  mean_test_mae  mean_test_rmse  mean_test_time  \
# 0         5.877333      90.962890       91.043803        0.661000
# 1        29.708333      90.962890       91.043803        0.597000
# 2        58.944000      90.962890       91.043803        0.588333
# 3       297.842000      90.962890       91.043803        0.628667
# 4        12.427333      90.962890       91.043803        0.620667
# 5        63.386667      90.962890       91.043803        0.650333
# 6       126.749667      90.962890       91.043803        0.610333
# 7       635.461333      90.962890       91.043803        0.621333
# 8        23.448667      90.962890       91.043803        0.647000
# 9       119.872000      90.962890       91.043803        0.636000
# 10      240.554000      90.962890       91.043803        0.622000
# 11     1203.128333      90.962890       91.043803        0.622000
# 18          False        0.1000             100                2
# 19          False        0.1000             500                2
# 20          False        0.1000              10                5
# 21          False        0.1000              50                5
# 22          False        0.1000             100                5
# 23          False        0.1000             500                5
# 24          False        0.1000              10               10
# 25          False        0.1000              50               10
# 26          False        0.1000             100               10
# 27          False        0.1000             500               10
# 28          False        0.1000              10               50
# 29          False        0.1000              50               50
# ..            ...           ...             ...              ...
# 226         False        0.0001             100                2
# 227         False        0.0001             500                2
# 228         False        0.0001              10                5
# 229         False        0.0001              50                5
# 230         False        0.0001             100                5
# 231         False        0.0001             500                5
# 232         False        0.0001              10               10
# 233         False        0.0001              50               10
# 234         False        0.0001             100               10
# 235         False        0.0001             500               10
# 236         False        0.0001              10               50
# 237         False        0.0001              50               50
# 238         False        0.0001             100               50
# 239         False        0.0001             500               50
# 240         False        0.0001              10                2
# 241         False        0.0001              50                2
# 242         False        0.0001             100                2
# 243         False        0.0001             500                2
# 244         False        0.0001              10                5
# 245         False        0.0001              50                5
# 246         False        0.0001             100                5
# 247         False        0.0001             500                5
# 248         False        0.0001              10               10
# 249         False        0.0001              50               10
# 250         False        0.0001             100               10
# 251         False        0.0001             500               10
# 252         False        0.0001              10               50
# 253         False        0.0001              50               50
# 254         False        0.0001             100               50
# 255         False        0.0001             500               50
#
#      param_reg_all                                             params  \
# 0           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 1           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 2           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 3           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 4           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 5           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 6           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 7           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 8           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 9           0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 10          0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 11          0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 12          0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 13          0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 14          0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 15          0.1000  {u'lr_all': 0.1, u'reg_all': 0.1, u'biased': F...
# 16          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 17          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 18          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 19          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 20          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 21          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 22          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 23          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 24          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 25          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 26          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 27          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 28          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# 29          0.0100  {u'lr_all': 0.1, u'reg_all': 0.01, u'biased': ...
# ..             ...                                                ...
# 226         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 227         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 228         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 229         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 230         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 231         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 232         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 233         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 234         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 235         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 236         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 237         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 238         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 239         0.0010  {u'lr_all': 0.0001, u'reg_all': 0.001, u'biase...
# 240         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 241         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 242         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 243         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 244         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 245         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 246         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 247         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 248         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 249         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 250         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 251         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 252         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 253         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 254         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
# 255         0.0001  {u'lr_all': 0.0001, u'reg_all': 0.0001, u'bias...
#
#          ...        split0_test_mae  split0_test_rmse  split1_test_mae  \
# 0        ...              90.970979         91.047871        90.956640
# 1        ...              90.970979         91.047871        90.956640
# 2        ...              90.970979         91.047871        90.956640
# 3        ...              90.970979         91.047871        90.956640
# 4        ...              90.970979         91.047871        90.956640
# 5        ...              90.970979         91.047871        90.956640
# 6        ...              90.970979         91.047871        90.956640
# 7        ...              90.970979         91.047871        90.956640
# 8        ...              90.970979         91.047871        90.956640
# 9        ...              90.970979         91.047871        90.956640
# 10       ...              90.970979         91.047871        90.956640
# 11       ...              90.970979         91.047871        90.956640
# 12       ...              90.970979         91.047871        90.956640
# 13       ...              90.970979         91.047871        90.956640
# 14       ...              90.970979         91.047871        90.956640
# 15       ...              90.970979         91.047871        90.956640
# 16       ...              90.970979         91.047871        90.956640
# 17       ...              90.970979         91.047871        90.956640
# 18       ...              90.970979         91.047871        90.956640
# 19       ...              90.970979         91.047871        90.956640
# 20       ...              90.970979         91.047871        90.956640
# 21       ...              90.970979         91.047871        90.956640
# 22       ...              90.970979         91.047871        90.956640
# 23       ...              90.970979         91.047871        90.956640
# 24       ...              90.970979         91.047871        90.956640
# 25       ...              90.970979         91.047871        90.956640
# 26       ...              90.970979         91.047871        90.956640
# 27       ...              90.970979         91.047871        90.956640
# 28       ...              90.970979         91.047871        90.956640
# 29       ...              90.970979         91.047871        90.956640
# ..       ...                    ...               ...              ...
# 226      ...               0.350975          1.017277         0.354340
# 227      ...               0.317216          0.897415         0.317413
# 228      ...               0.350975          1.017277         0.354340
# 229      ...               0.350975          1.017277         0.354340
# 230      ...               0.350975          1.017277         0.354340
# 231      ...               0.303898          0.879713         0.293868
# 232      ...               0.350975          1.017277         0.354340
# 233      ...               0.350975          1.017277         0.354340
# 234      ...               0.350975          1.017277         0.354340
# 235      ...               0.293785          0.862839         0.290755
# 236      ...               0.350975          1.017277         0.354340
# 237      ...               0.350975          1.017277         0.354340
# 238      ...               0.350975          1.017277         0.354340
# 239      ...               0.282778          0.858865         0.286818
# 240      ...               0.350975          1.017277         0.354340
# 241      ...               0.350975          1.017277         0.354340
# 242      ...               0.350975          1.017277         0.354340
# 243      ...               0.317909          0.910295         0.304759
# 244      ...               0.350975          1.017277         0.354340
# 245      ...               0.350975          1.017277         0.354340
# 246      ...               0.350975          1.017277         0.354340
# 247      ...               0.307113          0.880417         0.302024
# 248      ...               0.350975          1.017277         0.354340
# 249      ...               0.350975          1.017277         0.354340
# 250      ...               0.350975          1.017277         0.354340
# 251      ...               0.302237          0.879929         0.297617
# 252      ...               0.350975          1.017277         0.354340
# 253      ...               0.350975          1.017277         0.354340
# 254      ...               0.350975          1.017277         0.354340
# 255      ...               0.282938          0.867486         0.285998
#
#      split1_test_rmse  split2_test_mae  split2_test_rmse  std_fit_time  \
# 0           91.040021        90.961052         91.043517      0.077740
# 1           91.040021        90.961052         91.043517      0.251892
# 2           91.040021        90.961052         91.043517      0.122836
# 3           91.040021        90.961052         91.043517      3.206859
# 4           91.040021        90.961052         91.043517      0.090349
# 5           91.040021        90.961052         91.043517      0.116620
# 6           91.040021        90.961052         91.043517      0.152775
# 7           91.040021        90.961052         91.043517      0.133452
# 8           91.040021        90.961052         91.043517      0.189966
# 9           91.040021        90.961052         91.043517      0.222200
# 10          91.040021        90.961052         91.043517      0.491268
# 11          91.040021        90.961052         91.043517      0.520269
# 12          91.040021        90.961052         91.043517      0.956844
# 13          91.040021        90.961052         91.043517      0.224260
# 14          91.040021        90.961052         91.043517      0.594778
# 15          91.040021        90.961052         91.043517     70.773365
# 16          91.040021        90.961052         91.043517      0.060052
# 17          91.040021        90.961052         91.043517      0.040942
# 18          91.040021        90.961052         91.043517      0.052804
# 23       0.005996       0.003211       0.002829
# 24       0.005996       0.003211       0.046914
# 25       0.005996       0.003211       0.048801
# 26       0.005996       0.003211       0.004082
# 27       0.005996       0.003211       0.047518
# 28       0.005996       0.003211       0.045365
# 29       0.005996       0.003211       0.048928
# ..            ...            ...            ...
# 226      0.001709       0.036819       0.048332
# 227      0.008518       0.039969       0.045792
# 228      0.001709       0.036819       0.012193
# 229      0.001709       0.036819       0.048256
# 230      0.001709       0.036819       0.007134
# 231      0.004267       0.031767       0.043022
# 232      0.001709       0.036819       0.051487
# 233      0.001709       0.036819       0.012120
# 234      0.001709       0.036819       0.048194
# 235      0.001619       0.034721       0.005249
# 236      0.001709       0.036819       0.040942
# 237      0.001709       0.036819       0.048111
# 238      0.001709       0.036819       0.054530
# 239      0.001673       0.044498       0.048321
# 240      0.001709       0.036819       0.003559
# 241      0.001709       0.036819       0.050467
# 242      0.001709       0.036819       0.046051
# 243      0.009729       0.022073       0.049033
# 244      0.001709       0.036819       0.046435
# 245      0.001709       0.036819       0.005793
# 246      0.001709       0.036819       0.047849
# 247      0.002105       0.036103       0.002944
# 248      0.001709       0.036819       0.049087
# 249      0.001709       0.036819       0.006128
# 250      0.001709       0.036819       0.037985
# 251      0.004739       0.042319       0.048610
# 252      0.001709       0.036819       0.010143
# 253      0.001709       0.036819       0.051390
# 254      0.001709       0.036819       0.050577
# 255      0.001254       0.040647       0.056326
#
# [256 rows x 22 columns]

# %%
#scatter plot

# %%
data.raw_ratings[:9]
# Out:
# [(17850.0, u'85123A', 1.3558192847772361, None),
#  (17850.0, 71053, 1.4658427977150026, None),
#  (17850.0, u'84406B', 1.3791350783666279, None),
#  (17850.0, u'84029G', 1.4200221946610678, None),
#  (17850.0, u'84029E', 1.3971118931341004, None),
#  (17850.0, 22752, 1.3845205198206991, None),
#  (17850.0, 21730, 1.4978541433097132, None),
#  (17850.0, 22633, 1.2250480946454314, None),
#  (17850.0, 22632, 1.2250480946454314, None)]

# %%
#data.df

# %%
#Train using best hyper parameters i.e. {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 50, 'n_epochs': 500}
algo = SVD(biased = False,lr_all=0.01, reg_all= 0.1, n_factors=50, n_epochs=100)

# %%
from surprise.model_selection import train_test_split
trainset, testset = train_test_split(data, test_size=.25)

# %%
# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)

# %%
# Predictions
predictions = algo.test(testset)

# %%
# Then compute RMSE
from surprise import accuracy
accuracy.rmse(predictions)
# Out:
# RMSE: 0.8511
# 0.8510983548613263

# %%
test_list = []
for i in testset:
    test_list.append(i[-1])

# %%
prediction_list = []
for i in predictions:
    prediction_list.append(i[3])

# %%
plt.scatter(prediction_list,test_list)

# %%
plt.plot(test_list,'g',label='Test_Norm_Amt_spent')
plt.plot(prediction_list,'r',label='Predicted_Amt_spent')
legend = plt.legend(loc='best', shadow=True, fontsize='x-large')
#legend.get_frame().set_facecolor('#00FFCC')
plt.xlabel('Users')
plt.ylabel('Amount Spent')
# Out:
# Text(0,0.5,u'Amount Spent')
